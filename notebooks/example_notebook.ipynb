# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(np.arange(10), np.arange(10), label='x = y')
ax.legend()
ax.set_title('example plot')
plt.show()
